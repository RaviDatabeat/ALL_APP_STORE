# %%
from typing import List, Dict, Optional

import pandas as pd
from lxml import html

def parse_vizio_apps_lxml(html_path: str) -> List[Dict[str, Optional[str]]]:
    with open(html_path, "r", encoding="utf-8") as f:
        content = f.read()

    tree = html.fromstring(content)

    # Step 1: Get categories from tab buttons
    category_buttons = tree.xpath('//button[contains(@class, "v20-tabs__accordion")]')
    categories = {
        btn.attrib.get("data-tab-index"): btn.text_content().strip()
        for btn in category_buttons if btn.attrib.get("data-tab-index") is not None
    }

    # Step 2: Extract apps and find links
    apps = []
    for elem in tree.xpath('//*[@data-app-name]'):
        # Climb up to find the category index
        tab_index = None
        parent = elem
        while parent is not None and tab_index is None:
            tab_index = parent.attrib.get("data-tab-index")
            parent = parent.getparent()

        # Step 3: Try to find a nearby external link
        link_elem = elem.xpath('.//a[contains(@class, "btn-primary") and starts-with(@href, "http")]')
        if not link_elem:
            link_elem = elem.xpath('.//following::a[contains(@class, "btn-primary") and starts-with(@href, "http")][1]')
        link = link_elem[0].attrib["href"] if link_elem else ""

        # Collect all app info
        app_info = {
            "data-app-name": elem.attrib.get("data-app-name", "").strip(),
            "data-app-id": elem.attrib.get("data-app-id", "").strip(),
            "data-bundle-id": elem.attrib.get("data-bundle-id", "").strip(),
            "data-developer-url": elem.attrib.get("data-developer-url", "").strip(),
            "Category": categories.get(tab_index, ""),
            "link": link
        }
        apps.append(app_info)

    return apps

# %%
apps_list = parse_vizio_apps_lxml("vizio.html")
apps_list
# Out:
# [{'data-app-name': 'watchfree',
#   'data-app-id': 'vizio.watchfree',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.vizio.com/en/watchfreeplus'},
#  {'data-app-name': 'netflix',
#   'data-app-id': 'vizio.netflix',
#   'data-bundle-id': 'vizio.netflix',
#   'data-developer-url': 'https://www.netflix.com/',
#   'Category': '',
#   'link': 'https://www.netflix.com/'},
#  {'data-app-name': 'prime video',
#   'data-app-id': 'vizio.amazon',
#   'data-bundle-id': 'vizio.primevideo',
#   'data-developer-url': 'https://www.primevideo.com/',
#   'Category': '',
#   'link': 'https://www.amazon.com/Amazon-Video/b/?&node=2858778011&ref=dvm_us_gc_wd_vizio_websitepv'},
#  {'data-app-name': 'starz',
#   'data-app-id': 'vizio.starz',
#   'data-bundle-id': 'vizio.starz',
#   'data-developer-url': 'https://www.starz.com/',
#   'Category': '',
#   'link': 'https://www.starz.com/vizio'},
#  {'data-app-name': 'disney',
#   'data-app-id': 'vizio.disney',
#   'data-bundle-id': 'vizio.disneyplus',
#   'data-developer-url': 'https://www.disneyplus.com/',
#   'Category': '',
#   'link': 'https://www.disneyplus.com/start?cid=DSS-OFFDEVICE-LP'},
#  {'data-app-name': 'espn',
#   'data-app-id': 'vizio.espn',
#   'data-bundle-id': 'vizio.espn',
#   'data-developer-url': 'https://www.espn.com/',
#   'Category': '',
#   'link': 'https://www.espn.com/activate'},
#  {'data-app-name': 'hulu',
#   'data-app-id': 'vizio.hulu',
#   'data-bundle-id': 'vizio.hulu',
#   'data-developer-url': 'https://www.hulu.com/',
#   'Category': '',
#   'link': 'https://www.hulu.com/start/viziotvsmartcast'},
#  {'data-app-name': 'apple',
#   'data-app-id': 'apple',
#   'data-bundle-id': 'vizio.appletv',
#   'data-developer-url': 'https://support.apple.com/',
#   'Category': '',
#   'link': 'https://link.apple.com/'},
#  {'data-app-name': 'max',
#   'data-app-id': 'vizio.max',
#   'data-bundle-id': 'vizio.max',
#   'data-developer-url': 'https://www.max.com/vizio',
#   'Category': '',
#   'link': 'https://www.max.com/vizio'},
#  {'data-app-name': 'youtubetv',
#   'data-app-id': 'vizio.youtubetv',
#   'data-bundle-id': 'vizio.youtubetv',
#   'data-developer-url': 'https://tv.youtube.com/',
#   'Category': '',
#   'link': 'https://tv.youtube.com/start'},
#  {'data-app-name': 'peacock',
#   'data-app-id': '',
#   'data-bundle-id': 'vizio.peacock',
#   'data-developer-url': 'https://www.peacocktv.com/',
#   'Category': '',
#   'link': 'https://www.peacocktv.com/partners/vizio'},
#  {'data-app-name': 'weathernation',
#   'data-app-id': 'vizio.weathernation',
#   'data-bundle-id': 'vizio.weathernation',
#   'data-developer-url': 'https://www.weathernationtv.com/',
#   'Category': '',
#   'link': 'https://www.weathernationtv.com/'},
#  {'data-app-name': 'philo',
#   'data-app-id': 'vizio.philo',
#   'data-bundle-id': 'vizio.philo',
#   'data-developer-url': 'https://philo.com/',
#   'Category': '',
#   'link': 'https://www.philo.tv/vizio'},
#  {'data-app-name': 'discoveryplus',
#   'data-app-id': 'vizio.discoveryplus',
#   'data-bundle-id': 'vizio.discoveryplus',
#   'data-developer-url': 'https://www.discoveryplus.com/',
#   'Category': '',
#   'link': 'https://auth.discoveryplus.com/product?flow=CTVMvpdLogin&affiliate=vizio'},
#  {'data-app-name': 'youtube',
#   'data-app-id': 'vizio.youtube',
#   'data-bundle-id': 'vizio.youtube',
#   'data-developer-url': 'https://support.google.com/youtube/',
#   'Category': '',
#   'link': 'https://www.youtube.com/'},
#  {'data-app-name': 'paramountplus',
#   'data-app-id': 'vizio.paramountplus',
#   'data-bundle-id': 'vizio.paramount+',
#   'data-developer-url': 'https://www.paramount.com/',
#   'Category': '',
#   'link': 'https://paramountplus.com/vizio'},
#  {'data-app-name': 'slingtv',
#   'data-app-id': 'vizio.slingtv',
#   'data-bundle-id': 'vizio.sling',
#   'data-developer-url': 'https://www.sling.com/app-ads.txt',
#   'Category': '',
#   'link': 'https://sling.com/vizio'},
#  {'data-app-name': 'nfl',
#   'data-app-id': 'vizio.nfl',
#   'data-bundle-id': 'vizio.nfl',
#   'data-developer-url': 'http://NFL.com/',
#   'Category': '',
#   'link': 'https://id.nfl.com/subscriptions/select/nflplus?platform=vizio'},
#  {'data-app-name': 'siriusxm',
#   'data-app-id': 'vizio.siriusxm',
#   'data-bundle-id': 'vizio.siriusxm',
#   'data-developer-url': 'https://www.siriusxm.com/',
#   'Category': '',
#   'link': 'https://www.siriusxm.com/vizio'},
#  {'data-app-name': 'amcplus',
#   'data-app-id': 'vizio.amcplus',
#   'data-bundle-id': 'vizio.amc+',
#   'data-developer-url': 'https://www.amcplus.com/',
#   'Category': '',
#   'link': 'https://www.amcplus.com/create?referrer=vizio'},
#  {'data-app-name': 'vix',
#   'data-app-id': 'vizio.vix',
#   'data-bundle-id': 'vizio.vix',
#   'data-developer-url': 'https://ViX.com/',
#   'Category': '',
#   'link': 'https://vix.com/es-es/vixplus-vizio'},
#  {'data-app-name': 'watchfree',
#   'data-app-id': 'vizio.watchfree',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.vizio.com/en/watchfreeplus'},
#  {'data-app-name': 'thecw',
#   'data-app-id': 'vizio.thecw',
#   'data-bundle-id': 'vizio.thecw',
#   'data-developer-url': 'https://thecw.com/',
#   'Category': '',
#   'link': 'https://go.cwtv.com/vizio'},
#  {'data-app-name': 'FILMRISE',
#   'data-app-id': 'vizio.filmrise',
#   'data-bundle-id': 'vizio.filmrise',
#   'data-developer-url': 'https://filmrise.com/',
#   'Category': '',
#   'link': 'https://filmrise.com/where-to-watch'},
#  {'data-app-name': 'tubi',
#   'data-app-id': 'vizio.tubitv',
#   'data-bundle-id': 'vizio.tubi',
#   'data-developer-url': 'https://tubitv.com/',
#   'Category': '',
#   'link': 'https://link.tubi.tv/9d0I4waUf0'},
#  {'data-app-name': 'Pluto TV',
#   'data-app-id': 'vizio.plutotv',
#   'data-bundle-id': 'vizio.plutotv',
#   'data-developer-url': 'https://www.paramount.com/',
#   'Category': '',
#   'link': 'https://pluto.tv/'},
#  {'data-app-name': 'youtube',
#   'data-app-id': 'vizio.youtube',
#   'data-bundle-id': 'vizio.youtube',
#   'data-developer-url': 'https://support.google.com/youtube/',
#   'Category': '',
#   'link': 'https://www.youtube.com/'},
#  {'data-app-name': 'xumoplay',
#   'data-app-id': 'vizio.xumoplay',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'http://play.xumo.com/'},
#  {'data-app-name': 'midnight-pulp',
#   'data-app-id': 'vizio.midnight-pulp',
#   'data-bundle-id': 'vizio.midnightpulp',
#   'data-developer-url': 'https://www.midnightpulp.com/',
#   'Category': '',
#   'link': 'https://bit.ly/VizioMP'},
#  {'data-app-name': 'fawesome',
#   'data-app-id': 'vizio.fawesome',
#   'data-bundle-id': 'vizio.fawesome.tv',
#   'data-developer-url': 'https://futuretodayinc.com/',
#   'Category': '',
#   'link': 'https://fawesome.tv/'},
#  {'data-app-name': 'dark-matter',
#   'data-app-id': 'vizio.dark-matter',
#   'data-bundle-id': 'vizio.darkmattertv',
#   'data-developer-url': 'https://DarkMatterTV.com/',
#   'Category': '',
#   'link': 'https://www.darkmattertv.com/'},
#  {'data-app-name': 'thearchive',
#   'data-app-id': 'vizio.thearchive',
#   'data-bundle-id': 'vizio.thearchive',
#   'data-developer-url': 'http://thearchive.tv/',
#   'Category': '',
#   'link': 'https://www.thearchive.com/vizio'},
#  {'data-app-name': 'electric-now',
#   'data-app-id': 'vizio.electric-now',
#   'data-bundle-id': 'vizio.electricnow',
#   'data-developer-url': 'http://electricnow.tv/',
#   'Category': '',
#   'link': 'https://www.electricnow.tv/'},
#  {'data-app-name': 'pbs',
#   'data-app-id': 'vizio.pbs',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.pbs.org/pbs-video-app/?source=vizio'},
#  {'data-app-name': 'distrotv',
#   'data-app-id': 'vizio.distrotv',
#   'data-bundle-id': 'vizio.distrotv',
#   'data-developer-url': 'https://distro.tv/ads.txt/',
#   'Category': '',
#   'link': 'https://www.distro.tv/'},
#  {'data-app-name': 'popstar!tv',
#   'data-app-id': 'vizio.popstar!tv',
#   'data-bundle-id': 'vizio.popstar!tv',
#   'data-developer-url': 'https://www.popstaronline.com/',
#   'Category': '',
#   'link': 'https://www.popstaronline.com/'},
#  {'data-app-name': 'freemoviesplus',
#   'data-app-id': 'vizio.freemoviesplus',
#   'data-bundle-id': 'vizio.freemoviesplus',
#   'data-developer-url': 'https://www.ott.studio/',
#   'Category': '',
#   'link': 'https://www.ott.studio/'},
#  {'data-app-name': 'filmzie',
#   'data-app-id': 'vizio.filmzie',
#   'data-bundle-id': 'vizio.filmzie',
#   'data-developer-url': 'https://filmzie.com/',
#   'Category': '',
#   'link': 'https://filmzie.com/home'},
#  {'data-app-name': 'filmriseblacktv',
#   'data-app-id': 'vizio.filmriseblacktv',
#   'data-bundle-id': 'vizio.filmriseblacktv',
#   'data-developer-url': 'https://filmrise.com/',
#   'Category': '',
#   'link': 'https://filmrise.com/where-to-watch'},
#  {'data-app-name': 'filmriseaction',
#   'data-app-id': 'vizio.filmriseaction',
#   'data-bundle-id': 'vizio.filmriseaction',
#   'data-developer-url': 'https://filmrise.com/',
#   'Category': '',
#   'link': 'https://filmrise.com/where-to-watch'},
#  {'data-app-name': 'filmrisewestern',
#   'data-app-id': 'vizio.filmrisewestern',
#   'data-bundle-id': 'vizio.filmrisewestern',
#   'data-developer-url': 'https://filmrise.com/',
#   'Category': '',
#   'link': 'https://filmrise.com/where-to-watch'},
#  {'data-app-name': 'filmrisetruecrime',
#   'data-app-id': 'vizio.filmrisetruecrime',
#   'data-bundle-id': 'vizio.filmrisetruecrime',
#   'data-developer-url': 'https://filmrise.com/',
#   'Category': '',
#   'link': 'https://filmrise.com/where-to-watch'},
#  {'data-app-name': 'indiebox',
#   'data-app-id': 'vizio.indiebox',
#   'data-bundle-id': 'vizio.indiebox',
#   'data-developer-url': 'https://castify.ai/',
#   'Category': '',
#   'link': 'https://indieboxfreemovies.com/'},
#  {'data-app-name': 'action+',
#   'data-app-id': 'vizio.action+',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.ott.studio/'},
#  {'data-app-name': 'comedy+',
#   'data-app-id': 'vizio.comedy+',
#   'data-bundle-id': 'vizio.comedyplus',
#   'data-developer-url': 'https://www.ott.studio/',
#   'Category': '',
#   'link': 'https://www.ott.studio/'},
#  {'data-app-name': 'familyflix+',
#   'data-app-id': 'vizio.familyflix+',
#   'data-bundle-id': 'vizio.familyflixplus',
#   'data-developer-url': 'https://www.ott.studio/',
#   'Category': '',
#   'link': 'https://www.ott.studio/'},
#  {'data-app-name': 'crime+',
#   'data-app-id': 'vizio.crime+',
#   'data-bundle-id': 'vizio.crimeplus',
#   'data-developer-url': 'https://www.ott.studio/',
#   'Category': '',
#   'link': 'https://www.ott.studio/'},
#  {'data-app-name': 'horror+',
#   'data-app-id': 'vizio.horror+',
#   'data-bundle-id': 'vizio.horrorplus',
#   'data-developer-url': 'https://www.ott.studio/',
#   'Category': '',
#   'link': 'https://www.ott.studio/'},
#  {'data-app-name': 'vhs+',
#   'data-app-id': 'vizio.vhs+',
#   'data-bundle-id': 'vizio.vhsplus',
#   'data-developer-url': 'https://www.ott.studio/',
#   'Category': '',
#   'link': 'https://www.ott.studio/'},
#  {'data-app-name': 'westerns+',
#   'data-app-id': 'vizio.westerns+',
#   'data-bundle-id': 'vizio.westernsplus',
#   'data-developer-url': 'https://www.ott.studio/',
#   'Category': '',
#   'link': 'https://www.ott.studio/'},
#  {'data-app-name': 'classicmovies+',
#   'data-app-id': 'vizio.classicmovies+',
#   'data-bundle-id': 'vizio.classicmoviesplus',
#   'data-developer-url': 'https://www.ott.studio/',
#   'Category': '',
#   'link': 'https://www.ott.studio/'},
#  {'data-app-name': 'mometu',
#   'data-app-id': 'vizio.mometu',
#   'data-bundle-id': 'vizio.mometu',
#   'data-developer-url': 'https://mometu.com/',
#   'Category': '',
#   'link': 'https://mometu.com/'},
#  {'data-app-name': 'filmrisehorror',
#   'data-app-id': 'vizio.filmrisehorror',
#   'data-bundle-id': 'vizio.filmrisehorror',
#   'data-developer-url': 'https://filmrise.com/',
#   'Category': '',
#   'link': 'https://filmrise.com/where-to-watch'},
#  {'data-app-name': 'filmrisescifi',
#   'data-app-id': 'vizio.filmrisescifi',
#   'data-bundle-id': 'vizio.filmrisesci-fi',
#   'data-developer-url': 'https://filmrise.com/',
#   'Category': '',
#   'link': 'https://filmrise.com/where-to-watch'},
#  {'data-app-name': 'filmrisecomedy',
#   'data-app-id': 'vizio.filmrisecomedy',
#   'data-bundle-id': 'vizio.filmrisecomedy',
#   'data-developer-url': 'https://filmrise.com/',
#   'Category': '',
#   'link': 'https://filmrise.com/where-to-watch'},
#  {'data-app-name': 'cineverse',
#   'data-app-id': 'cineverse',
#   'data-bundle-id': 'vizio.cineverse',
#   'data-developer-url': 'https://www.cineverse.com/',
#   'Category': '',
#   'link': 'https://www.cineverse.com/'},
#  {'data-app-name': 'todazon',
#   'data-app-id': 'vizio.todazon',
#   'data-bundle-id': 'vizio.todazon',
#   'data-developer-url': 'https://todazon.com/',
#   'Category': '',
#   'link': 'https://todazon.com/'},
#  {'data-app-name': 'freetv',
#   'data-app-id': 'vizio.freetv',
#   'data-bundle-id': 'vizio.freetv',
#   'data-developer-url': 'https://www.freetv.com/',
#   'Category': '',
#   'link': 'https://html5.freetv.com/'},
#  {'data-app-name': 'documentarymax',
#   'data-app-id': 'vizio.documentarymax',
#   'data-bundle-id': 'vizio.documentarymax',
#   'data-developer-url': 'https://www.ott.studio/',
#   'Category': '',
#   'link': 'https://www.ott.studio/'},
#  {'data-app-name': 'netflix',
#   'data-app-id': 'vizio.netflix',
#   'data-bundle-id': 'vizio.netflix',
#   'data-developer-url': 'https://www.netflix.com/',
#   'Category': '',
#   'link': 'https://www.netflix.com/'},
#  {'data-app-name': 'prime video',
#   'data-app-id': 'vizio.amazon',
#   'data-bundle-id': 'vizio.primevideo',
#   'data-developer-url': 'https://www.primevideo.com/',
#   'Category': '',
#   'link': 'https://www.amazon.com/Amazon-Video/b/?&node=2858778011&ref=dvm_us_gc_wd_vizio_websitepv'},
#  {'data-app-name': 'apple',
#   'data-app-id': 'apple',
#   'data-bundle-id': 'vizio.appletv',
#   'data-developer-url': 'https://support.apple.com/',
#   'Category': '',
#   'link': 'https://link.apple.com/'},
#  {'data-app-name': 'hulu',
#   'data-app-id': 'vizio.hulu',
#   'data-bundle-id': 'vizio.hulu',
#   'data-developer-url': 'https://www.hulu.com/',
#   'Category': '',
#   'link': 'https://www.hulu.com/start/viziotvsmartcast'},
#  {'data-app-name': 'hallmark',
#   'data-app-id': 'vizio.hallmark',
#   'data-bundle-id': 'vizio.hallmark+',
#   'data-developer-url': 'https://www.watchhallmarktv.com/',
#   'Category': '',
#   'link': 'https://www.hmnow.com/'},
#  {'data-app-name': 'peacock',
#   'data-app-id': '',
#   'data-bundle-id': 'vizio.peacock',
#   'data-developer-url': 'https://www.peacocktv.com/',
#   'Category': '',
#   'link': 'https://www.peacocktv.com/partners/vizio'},
#  {'data-app-name': 'paramountplus',
#   'data-app-id': 'vizio.paramountplus',
#   'data-bundle-id': 'vizio.paramount+',
#   'data-developer-url': 'https://www.paramount.com/',
#   'Category': '',
#   'link': 'https://paramountplus.com/vizio'},
#  {'data-app-name': 'starz',
#   'data-app-id': 'vizio.starz',
#   'data-bundle-id': 'vizio.starz',
#   'data-developer-url': 'https://www.starz.com/',
#   'Category': '',
#   'link': 'https://www.starz.com/vizio'},
#  {'data-app-name': 'Vudu',
#   'data-app-id': 'vizio.vudu',
#   'data-bundle-id': 'vizio.vudu',
#   'data-developer-url': 'https://www.vudu.com/',
#   'Category': '',
#   'link': 'https://www.vudu.com/'},
#  {'data-app-name': 'discoveryplus',
#   'data-app-id': 'vizio.discoveryplus',
#   'data-bundle-id': 'vizio.discoveryplus',
#   'data-developer-url': 'https://www.discoveryplus.com/',
#   'Category': '',
#   'link': 'https://auth.discoveryplus.com/product?flow=CTVMvpdLogin&affiliate=vizio'},
#  {'data-app-name': 'fubo',
#   'data-app-id': 'vizio.fubo',
#   'data-bundle-id': 'vizio.fubo',
#   'data-developer-url': 'https://www.fubo.tv/',
#   'Category': '',
#   'link': 'https://www.fubo.tv/vizio'},
#  {'data-app-name': 'movies anywhere',
#   'data-app-id': 'moviesanywhere',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://moviesanywhere.com/home'},
#  {'data-app-name': 'youtubetv',
#   'data-app-id': 'vizio.youtubetv',
#   'data-bundle-id': 'vizio.youtubetv',
#   'data-developer-url': 'https://tv.youtube.com/',
#   'Category': '',
#   'link': 'https://tv.youtube.com/start'},
#  {'data-app-name': 'brown-sugar',
#   'data-app-id': 'vizio.brown-sugar',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.brownsugar.com/vizio'},
#  {'data-app-name': 'row8',
#   'data-app-id': 'vizio.row8',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.row8.com/activate'},
#  {'data-app-name': 'bet-plus',
#   'data-app-id': 'vizio.bet-plus',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.bet.plus/activate'},
#  {'data-app-name': 'lifetimemovieclub',
#   'data-app-id': 'vizio.lifetimemovieclub',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://lifetimemovieclub.com/vizio'},
#  {'data-app-name': 'screambox',
#   'data-app-id': 'vizio.screambox',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://bit.ly/SBVizio'},
#  {'data-app-name': 'heretv',
#   'data-app-id': 'vizio.heretv',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://heretv.com/'},
#  {'data-app-name': 'shudder',
#   'data-app-id': 'vizio.shudder',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.shudder.com/vizio'},
#  {'data-app-name': 'amcplus',
#   'data-app-id': 'vizio.amcplus',
#   'data-bundle-id': 'vizio.amc+',
#   'data-developer-url': 'https://www.amcplus.com/',
#   'Category': '',
#   'link': 'https://www.amcplus.com/create?referrer=vizio'},
#  {'data-app-name': 'frndlytv',
#   'data-app-id': 'vizio.frndlytv',
#   'data-bundle-id': 'vizio.frndlytv',
#   'data-developer-url': 'https://www.frndlytv.com/',
#   'Category': '',
#   'link': 'https://frndlytv.com/vizio'},
#  {'data-app-name': 'philo',
#   'data-app-id': 'vizio.philo',
#   'data-bundle-id': 'vizio.philo',
#   'data-developer-url': 'https://philo.com/',
#   'Category': '',
#   'link': 'https://www.philo.tv/vizio'},
#  {'data-app-name': 'britbox',
#   'data-app-id': 'vizio.britbox',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://britbox.com/connect/vizio'},
#  {'data-app-name': 'highoctane',
#   'data-app-id': 'vizio.highoctane',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://highoctanefree.tv/'},
#  {'data-app-name': 'wildearth',
#   'data-app-id': 'vizio.wildearth',
#   'data-bundle-id': 'vizio.wildearthtv',
#   'data-developer-url': 'https://wildearth.tv/',
#   'Category': '',
#   'link': 'https://wildearth.tv/'},
#  {'data-app-name': 'qvc+andhsn+',
#   'data-app-id': 'vizio.qvc+andhsn+',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://plus.qvc.com/'},
#  {'data-app-name': 'discoverygo',
#   'data-app-id': 'vizio.discoverygo',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://go.discovery.com/'},
#  {'data-app-name': 'investigationdiscoverygo',
#   'data-app-id': 'vizio.investigationdiscoverygo',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.investigationdiscovery.com/'},
#  {'data-app-name': 'animalplanetgo',
#   'data-app-id': 'vizio.animalplanetgo',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.animalplanet.com/'},
#  {'data-app-name': 'sciencechannelgo',
#   'data-app-id': 'vizio.sciencechannelgo',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.sciencechannel.com/'},
#  {'data-app-name': 'fandor',
#   'data-app-id': 'vizio.fandor',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://bit.ly/FDVizio'},
#  {'data-app-name': 'acorntv',
#   'data-app-id': 'vizio.acorntv',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://acorn.tv/vizio?utm_source=VIZIO&utm_medium=partnership&utm_campaign=Spring2021Email'},
#  {'data-app-name': 'passionflix',
#   'data-app-id': 'vizio.passionflix',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://watch.passionflix.com/link/vizio'},
#  {'data-app-name': 'nosey',
#   'data-app-id': 'vizio.nosey',
#   'data-bundle-id': 'vizio.nosey',
#   'data-developer-url': 'https://nosey.com/',
#   'Category': '',
#   'link': 'https://www.nosey.com/pages/home/d/home'},
#  {'data-app-name': 'aecrimecentral',
#   'data-app-id': 'vizio.aecrimecentral',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.aecrimecentral.com/vizio'},
#  {'data-app-name': 'historyvault',
#   'data-app-id': 'vizio.historyvault',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://historyvault.com/vizio'},
#  {'data-app-name': 'sundancenow',
#   'data-app-id': 'vizio.sundancenow',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://sundancenow.com/vizio'},
#  {'data-app-name': 'Plex',
#   'data-app-id': 'vizio.plex',
#   'data-bundle-id': 'vizio.plex',
#   'data-developer-url': 'https://plex.tv/',
#   'Category': '',
#   'link': 'https://www.plex.tv/'},
#  {'data-app-name': 'annoyingorange',
#   'data-app-id': 'vizio.annoyingorange',
#   'data-bundle-id': 'vizio.annoyingorange',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://www.play.works/creators/annoying-orange'},
#  {'data-app-name': 'powernation',
#   'data-app-id': 'vizio.powernation',
#   'data-bundle-id': 'vizio.powernation',
#   'data-developer-url': 'https://www.powernationtv.com/',
#   'Category': '',
#   'link': 'https://www.powernationtv.com/'},
#  {'data-app-name': 'motorvision',
#   'data-app-id': 'vizio.motorvision',
#   'data-bundle-id': 'vizio.motorvisiontv',
#   'data-developer-url': 'https://motorvision.tv/',
#   'Category': '',
#   'link': 'https://video.motorvision.tv/payment'},
#  {'data-app-name': 'christmasplus',
#   'data-app-id': 'vizio.christmasplus',
#   'data-bundle-id': 'vizio.christmasplus',
#   'data-developer-url': 'https://www.ott.studio/',
#   'Category': '',
#   'link': 'https://www.ott.studio'},
#  {'data-app-name': 'curiositystream',
#   'data-app-id': 'vizio.curiositystream',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.curiositystream.com/vizio/'},
#  {'data-app-name': 'comedy-dynamics',
#   'data-app-id': 'vizio.comedy-dynamics',
#   'data-bundle-id': 'vizio.comedydynamics',
#   'data-developer-url': 'https://comedydynamics.com/',
#   'Category': '',
#   'link': 'https://www.flixfling.com/'},
#  {'data-app-name': 'FLIXFLING',
#   'data-app-id': 'vizio.flixfling',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.flixfling.com/'},
#  {'data-app-name': 'tvone',
#   'data-app-id': 'vizio.tvone',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://tvone.tv/'},
#  {'data-app-name': 'moviemania',
#   'data-app-id': 'vizio.moviemania',
#   'data-bundle-id': 'vizio.moviemania',
#   'data-developer-url': 'https://my-cast.tv',
#   'Category': '',
#   'link': 'https://my-cast.tv'},
#  {'data-app-name': 'autoallstars',
#   'data-app-id': 'vizio.autoallstars',
#   'data-bundle-id': 'vizio.autoallstars',
#   'data-developer-url': 'https://castify.ai/',
#   'Category': '',
#   'link': 'https://autoallstars.net/'},
#  {'data-app-name': 'blackvoices+',
#   'data-app-id': 'vizio.blackvoices+',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.ott.studio/'},
#  {'data-app-name': 'hacksmithindustries',
#   'data-app-id': 'vizio.hacksmithindustries',
#   'data-bundle-id': 'vizio.hacksmithindustries',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'shoplc',
#   'data-app-id': 'vizio.shoplc',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.shoplc.com/'},
#  {'data-app-name': 'man+river',
#   'data-app-id': 'vizio.man+river',
#   'data-bundle-id': 'vizio.manplusriver',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'screensaversplus',
#   'data-app-id': 'vizio.screensaversplus',
#   'data-bundle-id': 'vizio.screensaversplus',
#   'data-developer-url': 'https://www.ott.studio/',
#   'Category': '',
#   'link': 'https://www.ott.studio/'},
#  {'data-app-name': 'nilered',
#   'data-app-id': 'vizio.nilered',
#   'data-bundle-id': 'vizio.nilered',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'bryton',
#   'data-app-id': 'vizio.bryton',
#   'data-bundle-id': 'vizio.bryton',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'twinparanormal',
#   'data-app-id': 'vizio.twinparanormal',
#   'data-bundle-id': 'vizio.twinparanormal',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'bravo',
#   'data-app-id': 'vizio.bravo',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.bravotv.com/'},
#  {'data-app-name': 'drewdirksen',
#   'data-app-id': 'vizio.drewdirksen',
#   'data-bundle-id': 'vizio.drewdirksen',
#   'data-developer-url': 'https://play.works/tv-channels#AVOD',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'khabylame',
#   'data-app-id': 'vizio.khabylame',
#   'data-bundle-id': 'vizio.khabylame',
#   'data-developer-url': 'https://play.works/tv-channels#AVOD',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'screengallery',
#   'data-app-id': 'vizio.screengallery',
#   'data-bundle-id': 'vizio.screengallery',
#   'data-developer-url': 'https://screengallery.com/VizioSignUp/',
#   'Category': '',
#   'link': 'https://screengallery.com/VizioSignUp/'},
#  {'data-app-name': 'creatornation',
#   'data-app-id': 'vizio.creatornation',
#   'data-bundle-id': 'vizio.creatornation',
#   'data-developer-url': 'https://play.works/tv-channels#AVOD',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'criminallylisted',
#   'data-app-id': 'vizio.criminallylisted',
#   'data-bundle-id': 'vizio.criminallylisted',
#   'data-developer-url': 'https://play.works/tv-channels#AVOD',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'Newsy',
#   'data-app-id': 'vizio.newsy',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.newsy.com/?utm_source=Vizio&utm_medium=PartnerLink&utm_campaign=VZ-page'},
#  {'data-app-name': 'haystack',
#   'data-app-id': 'vizio.haystacktv',
#   'data-bundle-id': 'vizio.haystacktv',
#   'data-developer-url': 'https://www.haystack.tv/',
#   'Category': '',
#   'link': 'https://www.haystack.tv/'},
#  {'data-app-name': 'local-now',
#   'data-app-id': 'vizio.local-now',
#   'data-bundle-id': 'vizio.localnow',
#   'data-developer-url': 'https://localnow.com/',
#   'Category': '',
#   'link': 'https://localnow.com/'},
#  {'data-app-name': 'court-tv',
#   'data-app-id': 'vizio.court-tv',
#   'data-bundle-id': 'vizio.courttv',
#   'data-developer-url': 'https://www.courttv.com/',
#   'Category': '',
#   'link': 'https://www.courttv.com/title/court-tv-live-stream-web/'},
#  {'data-app-name': 'fox-nation',
#   'data-app-id': 'vizio.fox-nation',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://nation.foxnews.com/?cmpid=org=NAT::ag=paid::mc=partner::src=VIZIO::cmp=VIZIO::add=Vizio.comSVODApps_Partnership&utm_source=partner&utm_medium=VIZIO&utm_campaign=VIZIO&utm_content=Vizio.comSVODApps_Partnership'},
#  {'data-app-name': 'foxnews',
#   'data-app-id': 'vizio.foxnews',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.foxnews.com/'},
#  {'data-app-name': 'foxlocal',
#   'data-app-id': 'vizio.foxlocal',
#   'data-bundle-id': 'vizio.foxlocal',
#   'data-developer-url': 'https://www.foxlocal.com/',
#   'Category': '',
#   'link': 'https://www.foxlocal.com/'},
#  {'data-app-name': 'cbsnews',
#   'data-app-id': 'vizio.cbsnews',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.cbsnews.com/'},
#  {'data-app-name': 'nbc',
#   'data-app-id': 'vizio.nbc',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://nbc.app.link/Vd4a7iPIEM'},
#  {'data-app-name': 'verylocal',
#   'data-app-id': 'vizio.verylocal',
#   'data-bundle-id': 'vizio.verylocal',
#   'data-developer-url': 'https://verylocal.com/',
#   'Category': '',
#   'link': 'https://www.verylocal.com/'},
#  {'data-app-name': 'dailywire',
#   'data-app-id': 'vizio.dailywire',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.dailywire.com/'},
#  {'data-app-name': 'thefirst',
#   'data-app-id': 'vizio.thefirst',
#   'data-bundle-id': 'vizio.thefirst',
#   'data-developer-url': 'https://www.thefirsttv.com/',
#   'Category': '',
#   'link': 'https://www.thefirsttv.com/'},
#  {'data-app-name': 'newsmax',
#   'data-app-id': 'vizio.newsmax',
#   'data-bundle-id': 'vizio.newsmax',
#   'data-developer-url': 'https://www.newsmax.com/',
#   'Category': '',
#   'link': 'https://www.newsmaxplus.com/'},
#  {'data-app-name': 'theweatherchannel',
#   'data-app-id': 'vizio.theweatherchannel',
#   'data-bundle-id': 'vizio.theweatherchannel',
#   'data-developer-url': 'https://streamtwc.com/',
#   'Category': '',
#   'link': 'https://streamtwc.com/vizio'},
#  {'data-app-name': 'bloomberg',
#   'data-app-id': 'vizio.bloomberg',
#   'data-bundle-id': 'vizio.bloomberg',
#   'data-developer-url': 'https://www.bloomberg.com/',
#   'Category': '',
#   'link': 'https://www.bloomberg.com/'},
#  {'data-app-name': 'actionnewsjax',
#   'data-app-id': 'vizio.actionnewsjax',
#   'data-bundle-id': 'vizio.actionnewsjax',
#   'data-developer-url': 'https://www.actionnewsjax.com/',
#   'Category': '',
#   'link': 'https://cmg-ctv-w-apps.cmg.com/vizio/prd/ActionNewsJax/index.html'},
#  {'data-app-name': 'wsbnowchannel2',
#   'data-app-id': 'vizio.wsbnowchannel2',
#   'data-bundle-id': 'vizio.wsbnowchannel2',
#   'data-developer-url': 'https://www.wsbtv.com/',
#   'Category': '',
#   'link': 'https://cmg-ctv-w-apps.cmg.com/vizio/prd/WSBNowChannel2Atlanta/index.html'},
#  {'data-app-name': 'wpxichannel11news',
#   'data-app-id': 'vizio.wpxichannel11news',
#   'data-bundle-id': 'vizio.wpxichannel11news',
#   'data-developer-url': 'https://www.wpxi.com/',
#   'Category': '',
#   'link': 'https://cmg-ctv-w-apps.cmg.com/vizio/prd/WPXICh11NewsPittsburgh/index.html'},
#  {'data-app-name': 'wsocchannel9',
#   'data-app-id': 'vizio.wsocchannel9',
#   'data-bundle-id': 'vizio.wsocchannel9',
#   'data-developer-url': 'https://www.wsoctv.com/',
#   'Category': '',
#   'link': 'https://cmg-ctv-w-apps.cmg.com/vizio/prd/WSOCCh9NewsCharlotte/index.html'},
#  {'data-app-name': 'wftvnowchannel9',
#   'data-app-id': 'vizio.wftvnowchannel9',
#   'data-bundle-id': 'vizio.wftvnowchannel9',
#   'data-developer-url': 'https://www.wftv.com/',
#   'Category': '',
#   'link': 'https://cmg-ctv-w-apps.cmg.com/vizio/prd/WFTVNowChannel9Orlando/index.html'},
#  {'data-app-name': 'whiochannel7',
#   'data-app-id': 'vizio.whiochannel7',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://cmg-ctv-w-apps.cmg.com/vizio/prd/WHIOChannel7DaytonNews/index.html'},
#  {'data-app-name': 'boston25',
#   'data-app-id': 'vizio.boston25',
#   'data-bundle-id': 'vizio.boston25news',
#   'data-developer-url': 'https://www.boston25news.com/',
#   'Category': '',
#   'link': 'https://cmg-ctv-w-apps.cmg.com/vizio/prd/Boston25News/index.html'},
#  {'data-app-name': 'kusa+',
#   'data-app-id': 'vizio.kusa+',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.9news.com/'},
#  {'data-app-name': 'wusa+',
#   'data-app-id': 'vizio.wusa+',
#   'data-bundle-id': 'vizio.wusa9news',
#   'data-developer-url': 'https://www.wusa9.com/',
#   'Category': '',
#   'link': 'https://www.wusa9.com/'},
#  {'data-app-name': 'kare11+',
#   'data-app-id': 'vizio.kare11+',
#   'data-bundle-id': 'vizio.kare11news',
#   'data-developer-url': 'https://www.kare11.com/',
#   'Category': '',
#   'link': 'https://www.kare11.com/'},
#  {'data-app-name': 'abc10+',
#   'data-app-id': 'vizio.abc10+',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.abc10.com/'},
#  {'data-app-name': 'wnep+',
#   'data-app-id': 'vizio.wnep+',
#   'data-bundle-id': 'vizio.wnep',
#   'data-developer-url': 'https://www.wnep.com/',
#   'Category': '',
#   'link': 'https://www.wnep.com/'},
#  {'data-app-name': 'oanlive',
#   'data-app-id': 'vizio.oanlive',
#   'data-bundle-id': 'vizio.oanlive',
#   'data-developer-url': 'https://live.oann.com/home.ktv/',
#   'Category': '',
#   'link': 'https://live.oann.com/home.ktv?coupon=VIZIO'},
#  {'data-app-name': 'salemnews',
#   'data-app-id': 'vizio.salemnews',
#   'data-bundle-id': 'vizio.salemnewschannel',
#   'data-developer-url': 'https://salemnewschannel.com/',
#   'Category': '',
#   'link': 'https://salemnewschannel.com/'},
#  {'data-app-name': 'newson',
#   'data-app-id': 'vizio.newson',
#   'data-bundle-id': 'vizio.newson',
#   'data-developer-url': 'http://www.newson.us/',
#   'Category': '',
#   'link': 'https://newson.us/featured'},
#  {'data-app-name': 'nbcnews',
#   'data-app-id': 'vizio.nbcnews',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.nbcnews.com/'},
#  {'data-app-name': 'cnbc',
#   'data-app-id': 'vizio.cnbc',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.cnbc.com/'},
#  {'data-app-name': 'disney',
#   'data-app-id': 'vizio.disney',
#   'data-bundle-id': 'vizio.disneyplus',
#   'data-developer-url': 'https://www.disneyplus.com/',
#   'Category': '',
#   'link': 'https://www.disneyplus.com/start?cid=DSS-OFFDEVICE-LP'},
#  {'data-app-name': 'cocomelon',
#   'data-app-id': 'vizio.cocomelon',
#   'data-bundle-id': 'vizio.cocomelon',
#   'data-developer-url': 'https://futuretodayinc.com/',
#   'Category': '',
#   'link': 'https://cocomelon.com/'},
#  {'data-app-name': 'lego-tv',
#   'data-app-id': 'vizio.lego-tv',
#   'data-bundle-id': 'vizio.legotv',
#   'data-developer-url': 'https://futuretodayinc.com/',
#   'Category': '',
#   'link': 'https://www.lego.com/en-us/categories/games/lego-tv'},
#  {'data-app-name': 'pbs-kids',
#   'data-app-id': 'vizio.pbs-kids',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.pbskids.org/'},
#  {'data-app-name': 'TG',
#   'data-app-id': 'vizio.toongoogles',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.toongoggles.com/'},
#  {'data-app-name': 'dovechannel',
#   'data-app-id': 'vizio.dovechannel',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.dovechannel.com/vizio/'},
#  {'data-app-name': 'ninjakidztv',
#   'data-app-id': 'vizio.ninjakidztv',
#   'data-bundle-id': 'vizio.ninjakidstv',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'kidoodletv',
#   'data-app-id': 'vizio.kidoodletv',
#   'data-bundle-id': 'vizio.kidoodle.tv',
#   'data-developer-url': 'http://www.kidoodle.tv/',
#   'Category': '',
#   'link': 'https://www.kidoodle.tv/'},
#  {'data-app-name': 'sensical',
#   'data-app-id': 'vizio.sensical',
#   'data-bundle-id': 'vizio.sensical',
#   'data-developer-url': 'https://www.sensical.tv/',
#   'Category': '',
#   'link': 'https://sensical.tv/auth/guestprofile?utm_source=Vizio&utm_medium=Partnership&utm_campaign=Webpage'},
#  {'data-app-name': 'zoomi',
#   'data-app-id': 'vizio.zoomi',
#   'data-bundle-id': 'vizio.zoomi',
#   'data-developer-url': 'https://www.my-cast.tv/',
#   'Category': '',
#   'link': 'https://www.play.works/'},
#  {'data-app-name': 'pwkids',
#   'data-app-id': 'vizio.pwkids',
#   'data-bundle-id': 'vizio.pwkids',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://www.play.works/'},
#  {'data-app-name': 'beani',
#   'data-app-id': 'vizio.beani',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://beani.tv/'},
#  {'data-app-name': 'happykids',
#   'data-app-id': 'vizio.happykids',
#   'data-bundle-id': 'vizio.happykids.tv',
#   'data-developer-url': 'https://futuretodayinc.com/',
#   'Category': '',
#   'link': 'https://happykids.tv/'},
#  {'data-app-name': 'daystar',
#   'data-app-id': 'vizio.daystar',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.daystar.com/'},
#  {'data-app-name': 'gaby&alex',
#   'data-app-id': 'vizio.gaby&alex',
#   'data-bundle-id': 'vizio.gabyandalex',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/'},
#  {'data-app-name': 'likenastya',
#   'data-app-id': 'vizio.likenastya',
#   'data-bundle-id': 'vizio.likenastya',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/'},
#  {'data-app-name': 'gorgeousmovies',
#   'data-app-id': 'vizio.gorgeousmovies',
#   'data-bundle-id': 'vizio.gorgeousmovies',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'funhousefamily',
#   'data-app-id': 'vizio.funhousefamily',
#   'data-bundle-id': 'vizio.funhousefamily',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'payton',
#   'data-app-id': 'vizio.payton',
#   'data-bundle-id': 'vizio.payton',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'cartoonsplus',
#   'data-app-id': 'vizio.cartoonsplus',
#   'data-bundle-id': 'vizio.cartoonsplus',
#   'data-developer-url': 'https://www.ott.studio/',
#   'Category': '',
#   'link': 'https://www.ott.studio/'},
#  {'data-app-name': 'byutv',
#   'data-app-id': 'vizio.byutv',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.byutv.org/'},
#  {'data-app-name': 'intouchministries',
#   'data-app-id': 'vizio.intouchministries',
#   'data-bundle-id': 'vizio.intouchministries',
#   'data-developer-url': 'http://www.intouch.org/',
#   'Category': '',
#   'link': 'https://www.intouch.org/'},
#  {'data-app-name': 'thefunsquad',
#   'data-app-id': 'vizio.thefunsquad',
#   'data-bundle-id': 'vizio.thefunsquad',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'salishandjordanmatter',
#   'data-app-id': 'vizio.salishandjordanmatter',
#   'data-bundle-id': 'vizio.salishandjordanmatter',
#   'data-developer-url': 'https://play.works/tv-channels#AVOD',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'jianhaotan',
#   'data-app-id': 'vizio.jianhaotan',
#   'data-bundle-id': 'vizio.jianhaotan',
#   'data-developer-url': 'https://play.works/tv-channels#AVOD',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'espn',
#   'data-app-id': 'vizio.espn',
#   'data-bundle-id': 'vizio.espn',
#   'data-developer-url': 'https://www.espn.com/',
#   'Category': '',
#   'link': 'https://www.espn.com/activate'},
#  {'data-app-name': 'nfl',
#   'data-app-id': 'vizio.nfl',
#   'data-bundle-id': 'vizio.nfl',
#   'data-developer-url': 'http://NFL.com/',
#   'Category': '',
#   'link': 'https://id.nfl.com/subscriptions/select/nflplus?platform=vizio'},
#  {'data-app-name': 'brooke-burke',
#   'data-app-id': 'vizio.brooke-burke',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://brookeburkebody.vhx.tv/'},
#  {'data-app-name': 'foxsports',
#   'data-app-id': 'vizio.foxsports',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.foxsports.com/'},
#  {'data-app-name': 'trillertv',
#   'data-app-id': 'vizio.trillertv',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.trillertv.com/connect'},
#  {'data-app-name': 'cbs sports',
#   'data-app-id': 'cbssports',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.cbssports.com/?ftag=CBS-17-10abj3i'},
#  {'data-app-name': 'dazn',
#   'data-app-id': 'vizio.dazn',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.dazn.com'},
#  {'data-app-name': 'watchwpt',
#   'data-app-id': 'vizio.watchwpt',
#   'data-bundle-id': 'vizio.watchwpt',
#   'data-developer-url': 'https://www.worldpokertour.com/',
#   'Category': '',
#   'link': 'https://worldpokertour.tv/?utm_source=vizio&utm_medium=website&utm_campaign=WPT+on+Vizio%20&utm_id=wpt-vizio'},
#  {'data-app-name': 'myoutdoortv',
#   'data-app-id': 'vizio.myoutdoortv',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://app.myoutdoortv.com/?gclid=CjwKCAjw-rOaBhA9EiwAUkLV4u1yAzg-v0uMUykfmzSl-xxgGSSJIEepLLoaFYNHqd2XiMcWAoCvOhoC1zQQAvD_BwE'},
#  {'data-app-name': 'fishingtv',
#   'data-app-id': 'vizio.fishingtv',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.fishingtv.com/vizio'},
#  {'data-app-name': 'dudeperfect',
#   'data-app-id': 'vizio.dudeperfect',
#   'data-bundle-id': 'vizio.dudeperfect',
#   'data-developer-url': 'https://dudeperfect.com/',
#   'Category': '',
#   'link': 'https://dudeperfect.com/'},
#  {'data-app-name': 'motorvision',
#   'data-app-id': 'vizio.motorvision',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://video.motorvision.tv/payment'},
#  {'data-app-name': 'unreel',
#   'data-app-id': 'vizio.unreel',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://unreel.net/'},
#  {'data-app-name': 'carbontv',
#   'data-app-id': 'vizio.carbontv',
#   'data-bundle-id': 'vizio.carbontv',
#   'data-developer-url': 'https://www.carbontv.com/',
#   'Category': '',
#   'link': 'https://www.carbontv.com/'},
#  {'data-app-name': 'livgolf+',
#   'data-app-id': 'vizio.livgolf+',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.livgolfplus.com/'},
#  {'data-app-name': 'yesnetwork',
#   'data-app-id': 'vizio.yesnetwork',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://watchyesnetwork.com/register?partnerSource=vizio'},
#  {'data-app-name': 'chesstv',
#   'data-app-id': 'vizio.chesstv',
#   'data-bundle-id': 'vizio.chesstv',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'lightsoutsportstv',
#   'data-app-id': 'vizio.lightsoutsportstv',
#   'data-bundle-id': 'vizio.lightsoutsportstv',
#   'data-developer-url': 'LightsOutSportsTV.com/',
#   'Category': '',
#   'link': 'https://www.lightsoutsportstv.com/'},
#  {'data-app-name': 'billyperry',
#   'data-app-id': 'vizio.billyperry',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'brandonwilliam',
#   'data-app-id': 'vizio.brandonwilliam',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'nicksymmonds',
#   'data-app-id': 'vizio.nicksymmonds',
#   'data-bundle-id': '',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'nbcsports',
#   'data-app-id': 'vizio.nbcsports',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://vizioapp.nbc.co/'},
#  {'data-app-name': 'knighttime',
#   'data-app-id': 'vizio.knighttime',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.knighttimeplus.com/vizioTv'},
#  {'data-app-name': 'victory+',
#   'data-app-id': 'vizio.victory+',
#   'data-bundle-id': 'vizio.victoryplus',
#   'data-developer-url': 'https://victoryplus.com/',
#   'Category': '',
#   'link': 'https://victoryplus.com/'},
#  {'data-app-name': 'gothamsports',
#   'data-app-id': 'vizio.gothamsports',
#   'data-bundle-id': 'vizio.gotham(yesnetwork)',
#   'data-developer-url': 'https://www.yesnetwork.com/',
#   'Category': '',
#   'link': 'https://signup.gothamsports.com/?utm_source=ctv&utm_medium=ctv&utm_campaign=gotham_vizio_acq&utm_term=single_image&utm_content=carousel'},
#  {'data-app-name': 'monumental',
#   'data-app-id': 'vizio.monumental',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.monumentalsportsnetwork.com/?utm_source=vizio&utm_medium=app&utm_campaign=2425_stream'},
#  {'data-app-name': 'freelivesports',
#   'data-app-id': 'vizio.freelivesports',
#   'data-bundle-id': 'vizio.freelivesports',
#   'data-developer-url': 'https://www.freelivesports.tv/',
#   'Category': '',
#   'link': 'https://www.freelivesports.tv/'},
#  {'data-app-name': 'tennischannel',
#   'data-app-id': 'vizio.tennischannel',
#   'data-bundle-id': 'vizio.tennischannel',
#   'data-developer-url': 'https://www.tennischannel.com/en-us/page/mps?method=code&referrer=vizio',
#   'Category': '',
#   'link': 'https://www.tennischannel.com/en-us/page/mps?method=code&referrer=vizio'},
#  {'data-app-name': 'Iheart RADIO',
#   'data-app-id': 'vizio.iheartradio',
#   'data-bundle-id': 'vizio.iheartradio',
#   'data-developer-url': 'https://www.iheart.com/',
#   'Category': '',
#   'link': 'https://promo.pages.iheart.com/vizio/#/'},
#  {'data-app-name': 'pandora',
#   'data-app-id': '',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.pandora.com/'},
#  {'data-app-name': 'partytymekaraoke',
#   'data-app-id': 'vizio.partytymekaraoke',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.partytymestreaming.com/upgrade/vizio'},
#  {'data-app-name': 'amazonmusic',
#   'data-app-id': 'vizio.amazonmusic',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.amazon.com/music/vizio'},
#  {'data-app-name': 'siriusxm',
#   'data-app-id': 'vizio.siriusxm',
#   'data-bundle-id': 'vizio.siriusxm',
#   'data-developer-url': 'https://www.siriusxm.com/',
#   'Category': '',
#   'link': 'https://www.siriusxm.com/vizio'},
#  {'data-app-name': 'musicchoice',
#   'data-app-id': 'vizio.musicchoice',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://go.musicchoice.com/'},
#  {'data-app-name': 'tuneinradio',
#   'data-app-id': 'vizio.tuneinradio',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://vizio.tv.tunein.com/'},
#  {'data-app-name': 'kidzbop+',
#   'data-app-id': 'vizio.kidzbop+',
#   'data-bundle-id': 'vizio.kidzbopplus',
#   'data-developer-url': 'https://kidzbop.com/',
#   'Category': '',
#   'link': 'https://kidzbopplus.kidzbop.com/vizio'},
#  {'data-app-name': 'kantokaraoke',
#   'data-app-id': 'vizio.kantokaraoke',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'http://kanto.co/vizio'},
#  {'data-app-name': 'xite',
#   'data-app-id': 'vizio.xite',
#   'data-bundle-id': 'vizio.xite',
#   'data-developer-url': 'https://xite.com/',
#   'Category': '',
#   'link': 'https://xite.com/'},
#  {'data-app-name': 'stingraykaraoke',
#   'data-app-id': 'vizio.stingraykaraoke',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://ktv.stingray.com/vizio/#home'},
#  {'data-app-name': 'versekaraoke',
#   'data-app-id': 'vizio.versekaraoke',
#   'data-bundle-id': 'vizio.versekaraoke',
#   'data-developer-url': 'https://versekaraoke.com/',
#   'Category': '',
#   'link': 'https://versekaraoke.com/'},
#  {'data-app-name': 'bob-ross',
#   'data-app-id': 'vizio.bob-ross',
#   'data-bundle-id': 'vizio.bobross',
#   'data-developer-url': 'https://www.bobross.com/',
#   'Category': '',
#   'link': 'https://www.bobross.com/'},
#  {'data-app-name': 'go-traveler',
#   'data-app-id': 'vizio.go-traveler',
#   'data-bundle-id': 'vizio.gotraveler',
#   'data-developer-url': 'http://gotraveler.com/',
#   'Category': '',
#   'link': 'https://www.gotraveler.com/'},
#  {'data-app-name': 'ifood-tv',
#   'data-app-id': 'vizio.ifood-tv',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://iptv.fawesome.tv/?iptv=true&siteId=1&platform_id=1217562'},
#  {'data-app-name': 'foodnetworkgo',
#   'data-app-id': 'vizio.foodnetworkgo',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
# ...
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'http://kanto.co/vizio'},
#  {'data-app-name': 'xite',
#   'data-app-id': 'vizio.xite',
#   'data-bundle-id': 'vizio.xite',
#   'data-developer-url': 'https://xite.com/',
#   'Category': '',
#   'link': 'https://xite.com/'},
#  {'data-app-name': 'stingraykaraoke',
#   'data-app-id': 'vizio.stingraykaraoke',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://ktv.stingray.com/vizio/#home'},
#  {'data-app-name': 'versekaraoke',
#   'data-app-id': 'vizio.versekaraoke',
#   'data-bundle-id': 'vizio.versekaraoke',
#   'data-developer-url': 'https://versekaraoke.com/',
#   'Category': '',
#   'link': 'https://versekaraoke.com/'},
#  {'data-app-name': 'bob-ross',
#   'data-app-id': 'vizio.bob-ross',
#   'data-bundle-id': 'vizio.bobross',
#   'data-developer-url': 'https://www.bobross.com/',
#   'Category': '',
#   'link': 'https://www.bobross.com/'},
#  {'data-app-name': 'go-traveler',
#   'data-app-id': 'vizio.go-traveler',
#   'data-bundle-id': 'vizio.gotraveler',
#   'data-developer-url': 'http://gotraveler.com/',
#   'Category': '',
#   'link': 'https://www.gotraveler.com/'},
#  {'data-app-name': 'ifood-tv',
#   'data-app-id': 'vizio.ifood-tv',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://iptv.fawesome.tv/?iptv=true&siteId=1&platform_id=1217562'},
#  {'data-app-name': 'foodnetworkgo',
#   'data-app-id': 'vizio.foodnetworkgo',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://watch.foodnetwork.com/'},
#  {'data-app-name': 'hgtvgo',
#   'data-app-id': 'vizio.hgtvgo',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://watch.hgtv.com/'},
#  {'data-app-name': 'tlcgo',
#   'data-app-id': 'vizio.tlcgo',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://go.tlc.com/'},
#  {'data-app-name': 'madeitmyselftv',
#   'data-app-id': 'vizio.madeitmyselftv',
#   'data-bundle-id': 'vizio.madeitmyselftv',
#   'data-developer-url': 'https://www.madeitmyselftv.com/',
#   'Category': '',
#   'link': 'https://www.madeitmyselftv.com/'},
#  {'data-app-name': 'brbfoodandtravel',
#   'data-app-id': 'vizio.brbfoodandtravel',
#   'data-bundle-id': 'vizio.brbtravel&food',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'fashiontv',
#   'data-app-id': 'vizio.fashiontv',
#   'data-bundle-id': 'vizio.fashiontv',
#   'data-developer-url': 'https://castify.ai/',
#   'Category': '',
#   'link': 'https://www.fashiontv.com/'},
#  {'data-app-name': 'own',
#   'data-app-id': 'vizio.own',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.oprah.com/sp/watch-own.html'},
#  {'data-app-name': 'athomewithfamilyhandyman',
#   'data-app-id': 'vizio.athomewithfamilyhandyman',
#   'data-bundle-id': 'vizio.athomewithfamilyhandyman',
#   'data-developer-url': 'https://familyhandyman.tv/',
#   'Category': '',
#   'link': 'https://familyhandyman.tv/'},
#  {'data-app-name': 'thepetcollective',
#   'data-app-id': 'vizio.thepetcollective',
#   'data-bundle-id': 'vizio.thepetcollective',
#   'data-developer-url': 'https://thepetcollective.tv/',
#   'Category': '',
#   'link': 'https://thepetcollective.com/'},
#  {'data-app-name': 'failarmy',
#   'data-app-id': 'vizio.failarmy',
#   'data-bundle-id': 'vizio.failarmy',
#   'data-developer-url': 'https://failarmy.tv/',
#   'Category': '',
#   'link': 'https://www.failarmy.com/'},
#  {'data-app-name': 'strictlydumpling',
#   'data-app-id': 'vizio.strictlydumpling',
#   'data-bundle-id': 'vizio.strictlydumpling',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'parkschannel',
#   'data-app-id': 'vizio.parkschannel',
#   'data-bundle-id': 'vizio.parkschannel',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'dannygrubs',
#   'data-app-id': 'vizio.dannygrubs',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'firekitchen',
#   'data-app-id': 'vizio.firekitchen',
#   'data-bundle-id': 'vizio.firekitchen',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'katinaeatskilos',
#   'data-app-id': 'vizio.katinaeatskilos',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'retro-crush',
#   'data-app-id': 'vizio.retro-crush',
#   'data-bundle-id': 'vizio.retrocrush',
#   'data-developer-url': 'https://www.retrocrush.tv/',
#   'Category': '',
#   'link': 'https://bit.ly/vizioRC'},
#  {'data-app-name': 'Free Games',
#   'data-app-id': 'free-games',
#   'data-bundle-id': 'vizio.freegamesbyplayworks',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://www.play.works/'},
#  {'data-app-name': 'tubi',
#   'data-app-id': 'vizio.tubitv',
#   'data-bundle-id': 'vizio.tubi',
#   'data-developer-url': 'https://tubitv.com/',
#   'Category': '',
#   'link': 'https://link.tubi.tv/9d0I4waUf0'},
#  {'data-app-name': 'TV Games',
#   'data-app-id': 'vizio.tvgames',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'http://tvgam.es/'},
#  {'data-app-name': 'ssundee',
#   'data-app-id': 'vizio.ssundee',
#   'data-bundle-id': 'vizio.ssundee',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://www.play.works'},
#  {'data-app-name': 'dantdm',
#   'data-app-id': 'vizio.dantdm',
#   'data-bundle-id': 'vizio.dantdm',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'bestofroblox',
#   'data-app-id': 'vizio.bestofroblox',
#   'data-bundle-id': 'vizio.bestofroblox',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'bestofminecraft',
#   'data-app-id': 'vizio.bestofminecraft',
#   'data-bundle-id': 'vizio.bestofminecraft',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'bestofamongus',
#   'data-app-id': 'vizio.bestofamongus',
#   'data-bundle-id': 'vizio.bestofamongus',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'bestoffortnite',
#   'data-app-id': 'vizio.bestoffortnite',
#   'data-bundle-id': 'vizio.bestoffortnite',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'kwebbelkop',
#   'data-app-id': 'vizio.kwebbelkop',
#   'data-bundle-id': 'vizio.kwebbelkop',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'bloo',
#   'data-app-id': 'vizio.bloo',
#   'data-bundle-id': 'vizio.bloo',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'bestofgaminganimation',
#   'data-app-id': 'vizio.bestofgaminganimation',
#   'data-bundle-id': 'vizio.bestofgaminganimation',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'bricksobrian',
#   'data-app-id': 'vizio.bricksobrian',
#   'data-bundle-id': 'vizio.brickso’brian',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'ethangamer',
#   'data-app-id': 'vizio.ethangamer',
#   'data-bundle-id': 'vizio.ethangamer',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'fnafgaming',
#   'data-app-id': 'vizio.fnafgaming',
#   'data-bundle-id': 'vizio.fnafgaming',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'daylinsfunhouse',
#   'data-app-id': 'vizio.daylinsfunhouse',
#   'data-bundle-id': 'vizio.daylin’sfunhouse',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'ali-a',
#   'data-app-id': 'vizio.ali-a',
#   'data-bundle-id': 'vizio.ali-a',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'letmeexplainstudios',
#   'data-app-id': 'vizio.letmeexplainstudios',
#   'data-bundle-id': 'vizio.letmeexplainstudios',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'eystreem',
#   'data-app-id': 'vizio.eystreem',
#   'data-bundle-id': 'vizio.eystreem',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'firelight',
#   'data-app-id': 'vizio.firelight',
#   'data-bundle-id': 'vizio.firelight',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'miloandchip',
#   'data-app-id': 'vizio.miloandchip',
#   'data-bundle-id': 'vizio.miloandchip',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'officialnoobie',
#   'data-app-id': 'vizio.officialnoobie',
#   'data-bundle-id': 'vizio.officialnoobie',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'meenyu',
#   'data-app-id': 'vizio.meenyu',
#   'data-bundle-id': 'vizio.meenyu',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'bumpybyssundee',
#   'data-app-id': 'vizio.bumpybyssundee',
#   'data-bundle-id': 'vizio.bumpybyssundee',
#   'data-developer-url': 'https://play.works/',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'fitmc',
#   'data-app-id': 'vizio.fitmc',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'gametoons',
#   'data-app-id': 'vizio.gametoons',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'muselk',
#   'data-app-id': 'vizio.muselk',
#   'data-bundle-id': 'vizio.muselk',
#   'data-developer-url': 'https://play.works/tv-channels#AVOD',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'beckbrojack',
#   'data-app-id': 'vizio.beckbrojack',
#   'data-bundle-id': 'vizio.beckbrojack',
#   'data-developer-url': 'https://play.works/tv-channels#AVOD',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'treyten',
#   'data-app-id': 'vizio.treyten',
#   'data-bundle-id': 'vizio.treyten',
#   'data-developer-url': 'https://play.works/tv-channels#AVOD',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'hidive',
#   'data-app-id': 'vizio.hidive',
#   'data-bundle-id': 'vizio.hidive',
#   'data-developer-url': 'https://www.hidive.com/vizio',
#   'Category': '',
#   'link': 'https://www.hidive.com/vizio'},
#  {'data-app-name': 'xnestorio',
#   'data-app-id': 'vizio.xnestorio',
#   'data-bundle-id': 'vizio.xnestorio',
#   'data-developer-url': 'https://play.works/tv-channels#AVOD',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'aussieantics',
#   'data-app-id': 'vizio.aussieantics',
#   'data-bundle-id': 'vizio.aussieantics',
#   'data-developer-url': 'https://play.works/tv-channels#AVOD',
#   'Category': '',
#   'link': 'https://play.works/tv-channels#AVOD'},
#  {'data-app-name': 'run-time',
#   'data-app-id': 'vizio.run-time',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.canela.tv/'},
#  {'data-app-name': 'canela-tv',
#   'data-app-id': 'vizio.canela-tv',
#   'data-bundle-id': 'vizio.canela.tv',
#   'data-developer-url': 'https://www.canela.tv/',
#   'Category': '',
#   'link': 'https://www.canela.tv/'},
#  {'data-app-name': 'vix',
#   'data-app-id': 'vizio.vix',
#   'data-bundle-id': 'vizio.vix',
#   'data-developer-url': 'https://ViX.com/',
#   'Category': '',
#   'link': 'https://vix.com/es-es/vixplus-vizio'},
#  {'data-app-name': 'phoenix-tv',
#   'data-app-id': 'vizio.phoenix-tv',
#   'data-bundle-id': 'vizio.phoenixtv',
#   'data-developer-url': 'https://phoenixTV.com/app-ads.txt',
#   'Category': '',
#   'link': 'https://www.thewutangcollection.com/vizio'},
#  {'data-app-name': 'wutang',
#   'data-app-id': 'vizio.wutang',
#   'data-bundle-id': 'vizio.wutangcollection',
#   'data-developer-url': 'https://www.thewutangcollection.com/',
#   'Category': '',
#   'link': 'https://www.thewutangcollection.com/vizio'},
#  {'data-app-name': 'asiancrush',
#   'data-app-id': 'vizio.asiancrush',
#   'data-bundle-id': 'vizio.asiancrush',
#   'data-developer-url': 'https://www.asiancrush.com/',
#   'Category': '',
#   'link': 'http://bit.ly/vizioAC'},
#  {'data-app-name': 'estrella',
#   'data-app-id': 'vizio.estrella',
#   'data-bundle-id': 'vizio.estrellatv',
#   'data-developer-url': 'https://ottera-est-web.s3.us-west-2.amazonaws.com/',
#   'Category': '',
#   'link': 'https://estrellatv.com/'},
#  {'data-app-name': 'kortv',
#   'data-app-id': 'vizio.kortv',
#   'data-bundle-id': 'vizio.kortv',
#   'data-developer-url': 'http://kortv.com',
#   'Category': '',
#   'link': 'https://bit.ly/VizioKORTV'},
#  {'data-app-name': 'afroland',
#   'data-app-id': 'vizio.afroland',
#   'data-bundle-id': 'vizio.afrolandtv',
#   'data-developer-url': 'https://www.afrolandtv.com/',
#   'Category': '',
#   'link': 'https://www.afrolandtv.com/'},
#  {'data-app-name': 'filmrisebritishtv',
#   'data-app-id': 'vizio.filmrisebritishtv',
#   'data-bundle-id': 'vizio.filmrisebritishtv',
#   'data-developer-url': 'https://filmrise.com/',
#   'Category': '',
#   'link': 'https://filmrise.com/where-to-watch'},
#  {'data-app-name': 'feliz7play',
#   'data-app-id': 'vizio.feliz7play',
#   'data-bundle-id': 'vizio.feliz7play',
#   'data-developer-url': 'https://www.my-cast.tv/',
#   'Category': '',
#   'link': 'https://feliz7play.com/es'},
#  {'data-app-name': 'chaupal',
#   'data-app-id': 'vizio.chaupal',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://chaupal.tv/'},
#  {'data-app-name': 'kocowa+',
#   'data-app-id': 'vizio.kocowa+',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://tvapp.prod.kocowacon.com/vz/index.html'},
#  {'data-app-name': 'iqiyi',
#   'data-app-id': 'vizio.iqiyi',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.iq.com/?lang=en_us'},
#  {'data-app-name': 'peliculasgratis',
#   'data-app-id': 'vizio.peliculasgratis',
#   'data-bundle-id': 'vizio.peliculasgratisplus',
#   'data-developer-url': 'https://www.ott.studio/',
#   'Category': '',
#   'link': 'https://www.ott.studio/'},
#  {'data-app-name': 'bingekorea',
#   'data-app-id': 'vizio.bingekorea',
#   'data-bundle-id': 'vizio.bingekorea',
#   'data-developer-url': 'https://its-newid.net/',
#   'Category': '',
#   'link': 'https://paro-vizio.its-newid.net/'},
#  {'data-app-name': 'telemundo',
#   'data-app-id': 'vizio.telemundo',
#   'data-bundle-id': '',
#   'data-developer-url': '',
#   'Category': '',
#   'link': 'https://www.telemundo.com/'},
#  {'data-app-name': 'amasiantv',
#   'data-app-id': 'vizio.amasiantv',
#   'data-bundle-id': 'vizio.amasiantv',
#   'data-developer-url': 'https://amasian.tv/live/amasian-tv-movies-and-more',
#   'Category': '',
#   'link': 'https://amasian.tv/live/amasian-tv-movies-and-more'},
#  {'data-app-name': 'haapitv',
#   'data-app-id': 'vizio.haapitv',
#   'data-bundle-id': '',
#   'data-developer-url': 'https://haapitv.com/',
#   'Category': '',
#   'link': 'https://haapitv.com/'}]

# %%
df = pd.DataFrame(apps_list)
df
# Out:
#        data-app-name            data-app-id             data-bundle-id  \
# 0          watchfree        vizio.watchfree
# 1            netflix          vizio.netflix              vizio.netflix
# 2        prime video           vizio.amazon           vizio.primevideo
# 3              starz            vizio.starz                vizio.starz
# 4             disney           vizio.disney           vizio.disneyplus
# ..               ...                    ...                        ...
# 573  peliculasgratis  vizio.peliculasgratis  vizio.peliculasgratisplus
# 574       bingekorea       vizio.bingekorea           vizio.bingekorea
# 575        telemundo        vizio.telemundo
# 576        amasiantv        vizio.amasiantv            vizio.amasiantv
# 577          haapitv          vizio.haapitv
#
#                                     data-developer-url Category  \
# 0
# 1                             https://www.netflix.com/
# 2                          https://www.primevideo.com/
# 3                               https://www.starz.com/
# 4                          https://www.disneyplus.com/
# ..                                                 ...      ...
# 573                            https://www.ott.studio/
# 574                             https://its-newid.net/
# 575
# 576  https://amasian.tv/live/amasian-tv-movies-and-...
# 577                               https://haapitv.com/
#
#                                                   link
# 0               https://www.vizio.com/en/watchfreeplus
# 1                             https://www.netflix.com/
# 2    https://www.amazon.com/Amazon-Video/b/?&node=2...
# 3                          https://www.starz.com/vizio
# 4    https://www.disneyplus.com/start?cid=DSS-OFFDE...
# ..                                                 ...
# 573                            https://www.ott.studio/
# 574                  https://paro-vizio.its-newid.net/
# 575                         https://www.telemundo.com/
# 576  https://amasian.tv/live/amasian-tv-movies-and-...
# 577                               https://haapitv.com/
#
# [578 rows x 6 columns]

# %%
df.to_parquet("philips_vizio_appstoday.parquet",index=False)
